# %%
import folium
from folium import plugins
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('/Users/mille/Desktop/gradcone2.csv')

# %%
df.head()
# Out:
#       Date     Latitude   Longitude  Elevation_m  Dominant_conifer  \
# 0  7/22/2012  39.417778 -105.751667    3041.9040    Lodge polepine
# 1  7/22/2012  39.416281 -105.751944    3053.1816             Aspen
# 2  7/22/2012  39.416967 -105.751111    3037.9416  Englanman spruce
# 3  7/22/2012  38.288222 -106.040278    2773.3752       Douglas fir
# 4  7/22/2012  38.287472 -106.033056    2718.8160       Douglas fir
#
#    Elevation_ft                        Location
# 0          9980                Kenosha Pass, CO
# 1         10017                Kenosha Pass, CO
# 2          9967                Kenosha Pass, CO
# 3          9099  Rio Grande National Forest, CO
# 4          8920  Rio Grande National Forest, CO

# %%
m = folium.Map([39.4133, -105.7567], zoom_start=5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
    
for index, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  popup=row['Location'],
                  icon=folium.Icon(icon='cloud')
                 ).add_to(m)
m
# m.save('/Users/mille/Conifer_Map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
