# %%
import folium
from folium import plugins
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('/Users/mille/Desktop/WDFW-Hatcheries.csv')

# %%
df.head()
# Out:
#                       Facility_Name               Address Line 1  \
# 0  Gray Wolf River Acclimation Pond                          NaN
# 1                 Garrison Hatchery  Drwr A-9601 Steilacoom Blvd
# 2             Kalama Falls Hatchery   Box 3900 Kalama River Road
# 3                 Meseberg Hatchery      1871 Ringold River Road
# 4                       Dryden Pond                          NaN
#
#    Address Line 2    City State    Zip             Phone              Fax  \
# 0             NaN     NaN    WA    NaN               NaN              NaN
# 1             NaN  Tacoma    WA  98498  Work: 2535897246  Fax: 2535897098
# 2             NaN  Kalama    WA  98625  Work: 3606734825  Fax: 3606734827
# 3             NaN    Mesa    WA  99343  Work: 5092694448  Fax: 5092694408
# 4             NaN     NaN    WA    NaN               NaN              NaN
#
#    Latitude  Longitude          ...           \
# 0   47.9641  -123.1151          ...
# 1   47.1915  -122.5741          ...
# 2   46.0160  -122.7336          ...
# 3   46.5071  -119.2562          ...
# 4   47.5446  -120.5635          ...
#
#                      Cooperative Project Description Seasonal Activities  \
# 0                                                NaN                 NaN
# 1  Volunteer rearing (cooperative projects): None...                 NaN
# 2  Volunteer rearing (cooperative projects): 1<br...                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
#
#      County              WRIA Salmon Recovery Region  \
# 0   Clallam   ELWHA-DUNGENESS            Puget Sound
# 1    Pierce   CHAMBERS-CLOVER            Puget Sound
# 2   Cowlitz             LEWIS   Lower Columbia River
# 3  Franklin  ESQUATZEL COULEE                    NaN
# 4    Chelan         WENATCHEE   Upper Columbia River
#
#                            Lead Entity             PSC Code  \
# 0  North Olympic Peninsula Lead Entity    3F10806  180048 H
# 1            Pierce County Lead Entity  3F10513  120007 H01
# 2   Lower Columbia Fish Recovery Board    3F42001  270002 H
# 3                                  NaN  3F42001  360001 H06
# 4            Chelan County Lead Entity    3F42001  450030 H
#
#                                                Image     Last Updated  \
# 0                                                NaN  5/16/2012 10:57
# 1                                                NaN  5/16/2012 10:57
# 2                                                NaN  5/20/2016 16:50
# 3                                                NaN  5/16/2012 10:57
# 4  https://data.wa.gov/views/hjdc-v2n4/files/TgjA...  5/16/2012 10:57
#
#             GeoLocation
# 0  (47.9641, -123.1151)
# 1  (47.1915, -122.5741)
# 2   (46.016, -122.7336)
# 3  (46.5071, -119.2562)
# 4  (47.5446, -120.5635)
#
# [5 rows x 23 columns]

# %%
m = folium.Map([47.9641, -123.1151], zoom_start=4)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  popup=row['Facility_Name'],
                  icon=folium.Icon(icon='green')
                 ).add_to(m)
m
m.save('/Users/mille/Washington.html')
